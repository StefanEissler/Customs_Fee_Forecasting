# %%
import pandas as pd 

customer_a_matrix = pd.read_csv("../data/evaluation/customer_a_evaluation.csv")
customer_b_matrix = pd.read_csv("../data/evaluation/customer_b_evaluation.csv")
customer_c_matrix = pd.read_csv("../data/evaluation/customer_c_evaluation.csv")
customer_d_matrix = pd.read_csv("../data/evaluation/customer_d_evaluation.csv")
customer_e_matrix = pd.read_csv("../data/evaluation/customer_e_evaluation.csv")
customer_f_matrix = pd.read_csv("../data/evaluation/customer_f_evaluation.csv")
customer_g_matrix = pd.read_csv("../data/evaluation/customer_g_evaluation.csv")
customer_h_matrix = pd.read_csv("../data/evaluation/customer_h_evaluation.csv")
customer_i_matrix = pd.read_csv("../data/evaluation/customer_i_evaluation.csv")

customer_a_matrix['customer'] = 'a'
customer_b_matrix['customer'] = 'b'
customer_c_matrix['customer'] = 'c'
customer_d_matrix['customer'] = 'd'
customer_e_matrix['customer'] = 'e'
customer_f_matrix['customer'] = 'f'
customer_g_matrix['customer'] = 'g'
customer_h_matrix['customer'] = 'h'
customer_i_matrix['customer'] = 'i'

all_customers = pd.concat([customer_a_matrix, customer_b_matrix, customer_c_matrix,
                           customer_d_matrix, customer_e_matrix, customer_f_matrix,
                           customer_g_matrix, customer_h_matrix, customer_i_matrix])

all_customers.reset_index(drop=True, inplace=True)
all_customers.to_csv("../data/evaluation/all_customers.csv", sep=';', index=False)

all_customers
# Out:
#     Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0           8694.017167                          108.865947
# 1          10241.937640                          156.939553
# 2           3742.657960                           29.850593
# 3           3455.915765                           27.337565
# 4           4810.290717                           34.642038
# 5           5368.307348                           41.525106
# 6           3555.117699                           18.515338
# 7           6122.126471                           35.417151
# 8           2921.989997                           15.223976
# 9           2997.014709                           15.699486
# 10          6118.457477                           29.827476
# 11          6469.710167                           30.546284
# 12         16752.224503                           28.781761
# 13         25277.186357                           48.890100
# 14          7661.864654                           13.246259
# ...

# %% [markdown]
# # Cusomter A

# %%
customer_a_matrix = pd.read_csv("../data/evaluation/customer_a_evaluation.csv")
customer_a_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          8694.017167                          108.865947
# 1         10241.937640                          156.939553
# 2          3742.657960                           29.850593
# 3          3455.915765                           27.337565
# 4          4810.290717                           34.642038
# 5          5368.307348                           41.525106
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                   12.358955 -0.813344         -77.567369     arima
# 1                   14.559397 -1.154625         -91.377799       ets
# 2                    5.320364  0.596875           4.831447    forest
# 3                    4.912747  0.616707           0.023700   xgboost
# 4                    6.838055 -0.103020         -29.901638       rnn
# 5                    7.631302 -0.030493         -15.098169      lstm

# %%
customer_a_arima = pd.read_csv("../data/prediction/customer_a_arima_2024-04-19_10-34-49_prediction.csv")
customer_a_arima.plot(title="customer a arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'customer a arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_a_ets = pd.read_csv("../data/prediction/customer_a_ets_2024-04-19_10-34-59_prediction.csv")
customer_a_ets.plot(title="Cusomter a ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter a ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_a_forest = pd.read_csv("../data/prediction/customer_a_forest_2024-04-19_10-35-18_prediction.csv")
customer_a_forest.plot(title="Cusomter a forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter a forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_a_xgboost = pd.read_csv("../data/prediction/customer_a_xgboost_2024-04-19_10-35-22_prediction.csv")
customer_a_xgboost.plot(title="Cusomter a xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter a xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_a_rnn = pd.read_csv("../data/prediction/customer_a_rnn_2024-04-19_10-38-05_prediction.csv")
customer_a_rnn.plot(title="Cusomter a rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter a rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_a_lstm = pd.read_csv("../data/prediction/customer_a_lstm_2024-04-19_10-39-47_prediction.csv")
customer_a_lstm.plot(title="Cusomter a lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter a lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer B

# %%
customer_b_matrix = pd.read_csv("../data/evaluation/customer_b_evaluation.csv")
customer_b_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          3555.117699                           18.515338
# 1          6122.126471                           35.417151
# 2          2921.989997                           15.223976
# 3          2997.014709                           15.699486
# 4          6118.457477                           29.827476
# 5          6469.710167                           30.546284
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    1.293012 -0.102520          -8.650981     arima
# 1                    2.226645 -1.405886         -30.990837       ets
# 2                    1.062741  0.410769           6.086624    forest
# 3                    1.090028  0.359227           4.487804   xgboost
# 4                    2.225311 -0.934378          26.804948       rnn
# 5                    2.353063 -1.538991          25.986832      lstm

# %%
customer_b_arima = pd.read_csv("../data/prediction/customer_b_arima_2024-04-19_10-40-19_prediction.csv")
customer_b_arima.plot(title="Cusomter b arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_b_ets = pd.read_csv("../data/prediction/customer_b_ets_2024-04-19_10-40-22_prediction.csv")
customer_b_ets.plot(title="Cusomter b arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_b_forest = pd.read_csv("../data/prediction/customer_b_forest_2024-04-19_10-40-32_prediction.csv")
customer_b_forest.plot(title="Cusomter b forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_b_xgboost = pd.read_csv("../data/prediction/customer_b_xgboost_2024-04-19_10-40-39_prediction.csv")
customer_b_xgboost.plot(title="Cusomter b xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_b_rnn = pd.read_csv("../data/prediction/customer_b_rnn_2024-04-19_10-41-56_prediction.csv")
customer_b_rnn.plot(title="Cusomter b rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_b_lstm = pd.read_csv("../data/prediction/customer_b_lstm_2024-04-19_10-43-20_prediction.csv")
customer_b_lstm.plot(title="Cusomter b lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter b lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer C

# %%
customer_c_matrix = pd.read_csv("../data/evaluation/customer_c_evaluation.csv")
customer_c_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0         16752.224503                           28.781761
# 1         25277.186357                           48.890100
# 2          7661.864654                           13.246259
# 3          9122.948535                           15.746215
# 4         22674.982509                           42.237206
# 5         16816.704031                           28.870448
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    4.070571 -0.530133         -22.377348     arima
# 1                    6.142025 -2.189855         -42.351890       ets
# 2                    1.861733  0.628943          -1.408761    forest
# 3                    2.216757  0.496539          -5.490876   xgboost
# 4                    5.509723 -1.683590         -37.650657       rnn
# 5                    4.086238 -0.540120         -21.370401      lstm

# %%
customer_c_arima = pd.read_csv("../data/prediction/customer_c_arima_2024-04-19_10-44-22_prediction.csv")
customer_c_arima.plot(title="Cusomter c arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_c_ets = pd.read_csv("../data/prediction/customer_c_ets_2024-04-19_10-44-27_prediction.csv")
customer_c_ets.plot(title="Cusomter c ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_c_forest = pd.read_csv("../data/prediction/customer_c_forest_2024-04-19_10-44-35_prediction.csv")
customer_c_forest.plot(title="Cusomter c forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_c_xgboost = pd.read_csv("../data/prediction/customer_c_xgboost_2024-04-19_10-44-43_prediction.csv")
customer_c_xgboost.plot(title="Cusomter c xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_c_rnn = pd.read_csv("../data/prediction/customer_c_rnn_2024-04-19_10-47-43_prediction.csv")
customer_c_rnn.plot(title="Cusomter c rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_c_lstm = pd.read_csv("../data/prediction/customer_c_lstm_2024-04-19_10-49-30_prediction.csv")
customer_c_lstm.plot(title="Cusomter c lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter c lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer D

# %%
customer_d_matrix = pd.read_csv("../data/evaluation/customer_d_evaluation.csv")
customer_d_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0         10757.607462                           25.544186
# 1         11108.206082                           26.036769
# 2          6921.613014                           16.641565
# 3          7674.808217                           19.206720
# 4         10160.062988                           24.156889
# 5         11132.229894                           26.628032
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    2.717136 -0.243462          -7.832726     arima
# 1                    2.805689 -0.180044          11.834145       ets
# 2                    1.748248  0.389909          -1.344260    forest
# 3                    1.938488  0.291650          -7.573222   xgboost
# 4                    2.566209 -0.022151          -5.223121       rnn
# 5                    2.811757 -0.296379         -15.236811      lstm

# %%
customer_d_arima = pd.read_csv("../data/prediction/customer_d_arima_2024-04-19_10-50-02_prediction.csv")
customer_d_arima.plot(title="Cusomter d arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_d_ets = pd.read_csv("../data/prediction/customer_d_ets_2024-04-19_10-50-06_prediction.csv")
customer_d_ets.plot(title="Cusomter d ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_d_forest = pd.read_csv("../data/prediction/customer_d_forest_2024-04-19_10-50-12_prediction.csv")
customer_d_forest.plot(title="Cusomter d forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_d_xgboost = pd.read_csv("../data/prediction/customer_d_xgboost_2024-04-19_10-50-18_prediction.csv")
customer_d_xgboost.plot(title="Cusomter d xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_d_rnn = pd.read_csv("../data/prediction/customer_d_rnn_2024-04-19_10-54-03_prediction.csv")
customer_d_rnn.plot(title="Cusomter d rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_d_lstm = pd.read_csv("../data/prediction/customer_d_rnn_2024-04-19_10-54-03_prediction.csv")
customer_d_lstm.plot(title="Cusomter d lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter d lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer E

# %%
customer_e_matrix = pd.read_csv("../data/evaluation/customer_e_evaluation.csv")
customer_e_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          3940.528385                          115.388500
# 1          1963.251427                           36.315171
# 2          1093.680643                           22.875080
# 3          1426.673133                           27.491846
# 4          2251.853715                           49.666558
# 5          2536.803221                           57.738782
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                   16.168271 -5.337459         -74.830085     arima
# 1                    8.055362 -1.142797          34.664332       ets
# 2                    4.487450  0.384722           2.172640    forest
# 3                    5.853742 -0.563780           4.374340   xgboost
# 4                    9.239517 -1.334522         -37.893219       rnn
# 5                   10.408686 -1.862528         -44.703702      lstm

# %%
customer_e_arima = pd.read_csv("../data/prediction/customer_e_arima_2024-04-19_10-54-41_prediction.csv")
customer_e_arima.plot(title="Cusomter e arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_e_ets = pd.read_csv("../data/prediction/customer_e_ets_2024-04-19_10-54-44_prediction.csv")
customer_e_ets.plot(title="Cusomter e ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_e_forest = pd.read_csv("../data/prediction/customer_e_forest_2024-04-19_10-54-48_prediction.csv")
customer_e_forest.plot(title="Cusomter e forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_e_xgboost = pd.read_csv("../data/prediction/customer_e_xgboost_2024-04-19_10-54-52_prediction.csv")
customer_e_xgboost.plot(title="Cusomter e xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_e_rnn = pd.read_csv("../data/prediction/customer_e_rnn_2024-04-19_10-57-13_prediction.csv")
customer_e_rnn.plot(title="Cusomter e rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_e_lstm = pd.read_csv("../data/prediction/customer_e_lstm_2024-04-19_10-58-56_prediction.csv")
customer_e_lstm.plot(title="Cusomter e lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter e lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer F

# %%
customer_f_matrix = pd.read_csv("../data/evaluation/customer_f_evaluation.csv")
customer_f_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          4898.372444                           56.078156
# 1          6738.164337                           90.753567
# 2          2136.643751                           21.171354
# 3          2143.743807                           22.598676
# 4         10109.956562                          197.251820
# 5          3159.568621                           32.784794
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    5.488502 -1.503660         -46.560561     arima
# 1                    7.549942 -3.039173         -66.106592       ets
# 2                    2.394055  0.447577           0.476891    forest
# 3                    2.402011  0.413530          -0.355375   xgboost
# 4                   11.327950 -6.917580         -99.779236       rnn
# 5                    3.540216 -0.004808          -3.832002      lstm

# %%
customer_f_arima = pd.read_csv("../data/prediction/customer_f_arima_2024-04-19_10-59-29_prediction.csv")
customer_f_arima.plot(title="Cusomter f arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_f_ets = pd.read_csv("../data/prediction/customer_f_ets_2024-04-19_10-59-37_prediction.csv")
customer_f_ets.plot(title="Cusomter f ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_f_forest = pd.read_csv("../data/prediction/customer_f_forest_2024-04-19_10-59-43_prediction.csv")
customer_f_forest.plot(title="Cusomter f forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_f_xgboost = pd.read_csv("../data/prediction/customer_f_xgboost_2024-04-19_10-59-59_prediction.csv")
customer_f_xgboost.plot(title="Cusomter f xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_f_rnn = pd.read_csv("../data/prediction/customer_f_rnn_2024-04-19_11-04-50_prediction.csv")
customer_f_rnn.plot(title="Cusomter f rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_f_lstm = pd.read_csv("../data/prediction/customer_f_lstm_2024-04-19_11-07-53_prediction.csv")
customer_f_lstm.plot(title="Cusomter f lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter f lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer G

# %%
customer_g_matrix = pd.read_csv("../data/evaluation/customer_g_evaluation.csv")
customer_g_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          4580.828170                           81.764150
# 1          1099.346455                           38.066018
# 2           552.164294                           21.789252
# 3           589.182889                           20.417361
# 4          1077.163161                           36.652532
# 5          1129.870354                           39.194008
#
#    Mean Absolute Scaled Error         r2  Forecast Bias (%) modeltype
# 0                    6.967598 -12.832122         136.397302     arima
# 1                    1.672144  -0.000019          -0.440455       ets
# 2                    0.839861   0.744377           3.128551    forest
# 3                    0.896168   0.722109          -1.761954   xgboost
# 4                    1.638402  -0.083171          15.613065       rnn
# 5                    1.718572  -0.019212          -4.139525      lstm

# %%
customer_g_arima = pd.read_csv("../data/prediction/customer_g_arima_2024-04-19_11-13-59_prediction.csv")
customer_g_arima.plot(title="Cusomter g arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_g_ets = pd.read_csv("../data/prediction/customer_g_ets_2024-04-19_11-14-03_prediction.csv")
customer_g_ets.plot(title="Cusomter g ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
cusomter_g_forest = pd.read_csv("../data/prediction/customer_g_forest_2024-04-19_11-14-10_prediction.csv")
cusomter_g_forest.plot(title="Cusomter g forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_g_xgboost = pd.read_csv("../data/prediction/customer_g_xgboost_2024-04-19_11-14-16_prediction.csv")
customer_g_xgboost.plot(title="Cusomter g xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_g_rnn = pd.read_csv("../data/prediction/customer_g_rnn_2024-04-19_11-16-53_prediction.csv")
customer_g_rnn.plot(title="Cusomter g rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_g_lstm = pd.read_csv("../data/prediction/customer_g_lstm_2024-04-19_11-23-10_prediction.csv")
customer_g_lstm.plot(title="Cusomter g lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter g lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer H

# %%
customer_h_matrix = pd.read_csv("../data/evaluation/customer_h_evaluation.csv")
customer_h_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0         18684.634762                           57.506613
# 1         19721.605920                           61.272240
# 2          8527.397215                           27.410376
# 3          8594.456655                           26.086441
# 4         19734.197416                           61.709272
# 5         19661.060166                           61.226143
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    5.638199 -0.238034         -27.889225     arima
# 1                    5.951111 -0.445361         -37.955713       ets
# 2                    2.573193  0.726736          -1.524911    forest
# 3                    2.593428  0.687671          -0.974070   xgboost
# 4                    5.954911 -0.412869         -37.262927       rnn
# 5                    5.932841 -0.464491         -41.710004      lstm

# %%
customer_h_arima = pd.read_csv("../data/prediction/customer_h_arima_2024-04-22_08-48-57_prediction.csv")
customer_h_arima.plot(title="Cusomter h arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_h_ets = pd.read_csv("../data/prediction/customer_h_ets_2024-04-22_08-49-05_prediction.csv")
customer_h_ets.plot(title="Cusomter h ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_h_forest = pd.read_csv("../data/prediction/customer_h_forest_2024-04-22_08-49-15_prediction.csv")
customer_h_forest.plot(title="Cusomter h forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_h_xgboost = pd.read_csv("../data/prediction/customer_h_xgboost_2024-04-22_08-49-25_prediction.csv")
customer_h_xgboost.plot(title="Cusomter h xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_h_rnn = pd.read_csv("../data/prediction/customer_h_rnn_2024-04-22_08-53-34_prediction.csv")
customer_h_rnn.plot(title="Cusomter h rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_h_lstm = pd.read_csv("../data/prediction/customer_h_lstm_2024-04-22_08-55-44_prediction.csv")
customer_h_lstm.plot(title="Cusomter h lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter h lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %% [markdown]
# # Customer I

# %%
customer_i_matrix = pd.read_csv("../data/evaluation/customer_i_evaluation.csv")
customer_i_matrix
# Out:
#    Mean Absolute Error  Mean Absolute Percentage Error (%)  \
# 0          9889.279382                           47.716047
# 1          6579.494650                           28.776636
# 2          3753.975448                           16.408043
# 3          3759.299462                           16.507694
# 4          6634.061604                           29.019030
# 5          8051.568157                           36.309883
#
#    Mean Absolute Scaled Error        r2  Forecast Bias (%) modeltype
# 0                    9.784565 -1.428767         -34.525033     arima
# 1                    6.509827 -0.064069          -8.506738       ets
# 2                    3.714226  0.567979           1.635885    forest
# 3                    3.719494  0.569835          -1.879133   xgboost
# 4                    6.563816 -0.113044         -11.341757       rnn
# 5                    7.966313 -0.699010         -28.126303      lstm

# %%
customer_i_arima = pd.read_csv("../data/prediction/customer_i_arima_2024-04-22_08-57-52_prediction.csv")
customer_i_arima.plot(title="Cusomter i arima model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i arima model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_i_ets = pd.read_csv("../data/prediction/customer_i_ets_2024-04-22_08-58-00_prediction.csv")
customer_i_ets.plot(title="Cusomter i ets model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i ets model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_i_forest = pd.read_csv("../data/prediction/customer_i_forest_2024-04-22_08-58-16_prediction.csv")
customer_i_forest.plot(title="Cusomter i forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_i_xgboost = pd.read_csv("../data/prediction/customer_i_xgboost_2024-04-22_08-58-27_prediction.csv")
customer_i_xgboost.plot(title="Cusomter i xgboost model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i xgboost model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_i_rnn = pd.read_csv("../data/prediction/customer_i_rnn_2024-04-22_09-03-25_prediction.csv")
customer_i_rnn.plot(title="Cusomter i rnn model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i rnn model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>

# %%
customer_i_lstm = pd.read_csv("../data/prediction/customer_i_lstm_2024-04-22_09-05-34_prediction.csv")
customer_i_lstm.plot(title="Cusomter i lstm model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'Cusomter i lstm model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>
