# %%
import pandas as pd 


example_forest = pd.read_csv("../data/evaluation/example_forest_2024-04-18_15-38-44_evaluation.csv")
example_forest.plot(title="example customer forest model", xlabel="Tage", ylabel="Abgabe geleitender Durschnitt")
# Out:
# <Axes: title={'center': 'example customer forest model'}, xlabel='Tage', ylabel='Abgabe geleitender Durschnitt'>
